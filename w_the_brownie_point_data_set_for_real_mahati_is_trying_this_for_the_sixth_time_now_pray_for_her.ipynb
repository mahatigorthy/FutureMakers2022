# %% [markdown]
# <a href="https://colab.research.google.com/github/mahatigorthy/FutureMakers2022/blob/main/w_the_brownie_point_data_set_for_real_mahati_is_trying_this_for_the_sixth_time_now_pray_for_her.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##import libraries

import matplotlib.pyplot as plt

from nltk.stem import WordNetLemmatizer
import warnings
warnings.filterwarnings('ignore')
import requests
import time
import numpy as np
import pandas as pd

# %%
nRowsRead = 2699
df1 = pd.read_csv('/content/balanced_labelled_news_data_w_text (1).csv', delimiter=',', nrows = nRowsRead)
df1.dataframeName = 'newdata.csv'
nRow, nCol = df1.shape
print(f'There are {nRow} rows and {nCol} columns')
# Out:
# There are 2699 rows and 10 columns

# %%
df1.head(2699)
# Out:
#       Unnamed: 0                                                url       q3  \
# 0              0  http://www.latimes.com/news/nationworld/nation...     News
# 1              1  http://www.dailykos.com/story/2013/06/30/12189...  Opinion
# 2              2  http://www.dailykos.com/story/2013/10/18/12486...  Opinion
# 3              3  http://www.dailykos.com/story/2013/11/24/12568...     News
# 4              4  http://www.breitbart.com/Big-Government/2013/0...     News
# ...          ...                                                ...      ...
# 2694        3145  http://www.breitbart.com/Big-Government/2013/0...     News
# 2695        3146  http://news.yahoo.com/immigration-debate-clear...     News
# 2696        3147  http://www.washingtonpost.com/blogs/govbeat/wp...     News
# 2697        3148     http://www.bbc.co.uk/news/uk-politics-21319965     News
# 2698        3149  http://www.breitbart.com/Big-Government/2013/0...     News
#
# ...

# %%
#transforming the target into 1 for Democrats and 0 for Conservative
##df1['Party'] = df1['Party'].map(lambda x : 1 if x == 'Democrat' else 0)

##label -- 3 is neutral; 1 is democrat; 2 is republican

# %%
df1.head(2699)
# Out:
#       Unnamed: 0                                                url       q3  \
# 0              0  http://www.latimes.com/news/nationworld/nation...     News
# 1              1  http://www.dailykos.com/story/2013/06/30/12189...  Opinion
# 2              2  http://www.dailykos.com/story/2013/10/18/12486...  Opinion
# 3              3  http://www.dailykos.com/story/2013/11/24/12568...     News
# 4              4  http://www.breitbart.com/Big-Government/2013/0...     News
# ...          ...                                                ...      ...
# 2694        3145  http://www.breitbart.com/Big-Government/2013/0...     News
# 2695        3146  http://news.yahoo.com/immigration-debate-clear...     News
# 2696        3147  http://www.washingtonpost.com/blogs/govbeat/wp...     News
# 2697        3148     http://www.bbc.co.uk/news/uk-politics-21319965     News
# 2698        3149  http://www.breitbart.com/Big-Government/2013/0...     News
#
# ...

# %%
# import text based modules
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.feature_extraction import _stop_words

# %%
additional_politics_english_stop = ['www', 'things', 'does', 'x200b', 'amp', 'want', 'watch',
                           'just', 'like', 'https', 'com', 'republican', 'republicans',
                           'libertarians', 'democrats', 'democrat', 'people', 'libertarian',
                           'says', 'say', 'did', 'this', 'conservative', 'conservatives' ]

additional_english_stop = ['www', 'things', 'does', 'x200b', 'amp',
                           'just', 'like', 'https', 'com', 'watch', 'want',
                           'says', 'say', 'did', 'this']

new_stop_list = _stop_words.ENGLISH_STOP_WORDS.union(additional_english_stop)
new_politics_english_stop_list = _stop_words.ENGLISH_STOP_WORDS.union(additional_politics_english_stop)
print(len(_stop_words.ENGLISH_STOP_WORDS))
print(len(additional_english_stop))
print(len(new_politics_english_stop_list))
print(len(new_stop_list))
# Out:
# 318
# 15
# 341
# 332

# %%
# code originally written by boom
# Function to count words in each df
def word_counter(title_df,stop_list = []):
    
    # Count Vectorize
    cvec = CountVectorizer(stop_words = stop_list, max_features=15)

    # Transform the corpus
    X_text = cvec.fit_transform(title_df['Tweet'])

    # Converts text to array form
    X_text = pd.DataFrame(X_text.toarray(), columns= cvec.get_feature_names())

    # See word counts
    word_counts = X_text.sum().sort_values(0, ascending=False)
    
    return word_counts

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix
from xgboost import XGBClassifier
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,recall_score,precision_score, confusion_matrix

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0           0
# url                  0
# q3                   0
# perceived            0
# primary.topic        0
# secondary.topic      0
# democrat.vote        0
# republican.vote      0
# label                0
# text               167
# dtype: int64

# %%
df1 = df1.dropna(axis=0, how="any", thresh=None, subset=None, inplace=False)

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0         0
# url                0
# q3                 0
# perceived          0
# primary.topic      0
# secondary.topic    0
# democrat.vote      0
# republican.vote    0
# label              0
# text               0
# dtype: int64

# %%
import nltk as nltk

# %%
df1 = df1[['url',
                            'primary.topic',
                            'secondary.topic',
                            'label',
                            'text']]
df1 = df1.dropna()

# %%
from sklearn.preprocessing import OrdinalEncoder
ord_enc = OrdinalEncoder()
df1["url"] = ord_enc.fit_transform(df1[["url"]])
df1["primary.topic"] = ord_enc.fit_transform(df1[["primary.topic"]])
df1["secondary.topic"] = ord_enc.fit_transform(df1[["secondary.topic"]])

# %%
X = df1['text']
y = df1['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.75, test_size = 0.25, random_state=42, stratify= y)

# %%
## pre process using lemmitization 
from nltk.stem import WordNetLemmatizer
 
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
from nltk.tokenize import word_tokenize

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# lemmetization + tokenizing

# %%
##tt = word_tokenize()
print(lambda text: word_tokenize(text))
df1['text'] = df1['text'].map(lambda text: word_tokenize(text))
# Out:
# <function <lambda> at 0x7f1fbfa27c20>

# %%
lmtzr = WordNetLemmatizer()
df1['text'] = df1['text'].apply(
                    lambda lst:[lmtzr.lemmatize(word) for word in lst])

# %%
df1.isnull().sum()
# Out:
# url                0
# primary.topic      0
# secondary.topic    0
# label              0
# text               0
# dtype: int64

# %%
df1.head(2699)
# Out:
#          url  primary.topic  secondary.topic  label  \
# 0     1730.0            6.0             11.0      1
# 1     1174.0            5.0             13.0      1
# 2     1242.0           10.0             13.0      1
# 3     1261.0            3.0             13.0      1
# 4      680.0           12.0             13.0      1
# ...      ...            ...              ...    ...
# 2692  1361.0            5.0             13.0      3
# 2694   621.0            5.0             13.0      3
# 2696  2026.0            5.0             13.0      3
# 2697   480.0           11.0              7.0      3
# 2698   635.0           12.0             11.0      3
#
#                                                    text
# 0     [Obama, considers, sweeping, climate, plan, WA...
# 1     [Like, every, other, state, where, Republicans...
# 2     [Fox, News, Nation, strike, again, ., Sean, Ha...
# 3     [Rep., Paul, Ryan, 's, commitment, to, ending,...
# ...

# %%
y_test.value_counts(normalize=True)
# Out:
# 1    0.336493
# 3    0.331754
# 2    0.331754
# Name: label, dtype: float64

# %%
df1.head(2699)
# Out:
#          url  primary.topic  secondary.topic  label  \
# 0     1730.0            6.0             11.0      1
# 1     1174.0            5.0             13.0      1
# 2     1242.0           10.0             13.0      1
# 3     1261.0            3.0             13.0      1
# 4      680.0           12.0             13.0      1
# ...      ...            ...              ...    ...
# 2692  1361.0            5.0             13.0      3
# 2694   621.0            5.0             13.0      3
# 2696  2026.0            5.0             13.0      3
# 2697   480.0           11.0              7.0      3
# 2698   635.0           12.0             11.0      3
#
#                                                    text
# 0     [Obama, considers, sweeping, climate, plan, WA...
# 1     [Like, every, other, state, where, Republicans...
# 2     [Fox, News, Nation, strike, again, ., Sean, Ha...
# 3     [Rep., Paul, Ryan, 's, commitment, to, ending,...
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.ensemble import AdaBoostClassifier

# %%
from sklearn.svm import LinearSVC, SVC
from sklearn.model_selection import cross_val_score

# %%
##preprocess ecplicitly 
##before passing it through ADA pipeline, before vectorization, try to preprocess like stemming, lemmitization -- try other classifiers and let her know 
rf_pipe = Pipeline([
        ('tvec', TfidfVectorizer()),
        ('rfc', RandomForestClassifier())])

rf_params = [{
    'tvec__max_features': [None],
    'tvec__min_df': [4],
    'tvec__max_df': [.3,.4, .5],
    'tvec__ngram_range': [(1,1),(1,2),(1,3)],
    'tvec__stop_words': [None],
    'rfc__bootstrap': [False, True],
    'rfc__n_estimators': [10,100],
    'rfc__max_features': [.5, .6, .7],
    'rfc__min_samples_leaf': [10],
    'rfc__min_samples_split':[3]
}]

# %%
from sklearn.preprocessing import StandardScaler

# %%
df1.head(2699)
# Out:
#          url  primary.topic  secondary.topic  label  \
# 0     1730.0            6.0             11.0      1
# 1     1174.0            5.0             13.0      1
# 2     1242.0           10.0             13.0      1
# 3     1261.0            3.0             13.0      1
# 4      680.0           12.0             13.0      1
# ...      ...            ...              ...    ...
# 2692  1361.0            5.0             13.0      3
# 2694   621.0            5.0             13.0      3
# 2696  2026.0            5.0             13.0      3
# 2697   480.0           11.0              7.0      3
# 2698   635.0           12.0             11.0      3
#
#                                                    text
# 0     [Obama, considers, sweeping, climate, plan, WA...
# 1     [Like, every, other, state, where, Republicans...
# 2     [Fox, News, Nation, strike, again, ., Sean, Ha...
# 3     [Rep., Paul, Ryan, 's, commitment, to, ending,...
# ...

# %%
gs= GridSearchCV(rf_pipe, 
                   param_grid=rf_params, 
                   cv = 4,
                   verbose = 1,
                   n_jobs = 3)

gs.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 108 candidates, totalling 432 fits
# GridSearchCV(cv=4,
#              estimator=Pipeline(steps=[('tvec', TfidfVectorizer()),
#                                        ('rfc', RandomForestClassifier())]),
#              n_jobs=3,
#              param_grid=[{'rfc__bootstrap': [False, True],
#                           'rfc__max_features': [0.5, 0.6, 0.7],
#                           'rfc__min_samples_leaf': [10],
#                           'rfc__min_samples_split': [3],
#                           'rfc__n_estimators': [10, 100],
#                           'tvec__max_df': [0.3, 0.4, 0.5],
#                           'tvec__max_features': [None], 'tvec__min_df': [4],
#                           'tvec__ngram_range': [(1, 1), (1, 2), (1, 3)],
#                           'tvec__stop_words': [None]}],
#              verbose=1)

# %%
tfrf_bestscore = gs.best_score_
tfrf_params = gs.best_params_
tfrf_train = gs.score(X_train,y_train)
tfrf_test= gs.score(X_test,y_test)
tfrf = ('TF-IDF with RandomForest', tfrf_bestscore, tfrf_params, tfrf_train, tfrf_test)

# %%
print(f'Best Score: {gs.best_score_}')
print(f'Best Parameters: {gs.best_params_}')
print(f'Train Accuracy Score: {gs.score(X_train,y_train)}')
print(f'Test Accuracy Score: {gs.score(X_test,y_test)}')
# Out:
# Best Score: 0.5639751276926493
# Best Parameters: {'rfc__bootstrap': True, 'rfc__max_features': 0.6, 'rfc__min_samples_leaf': 10, 'rfc__min_samples_split': 3, 'rfc__n_estimators': 100, 'tvec__max_df': 0.5, 'tvec__max_features': None, 'tvec__min_df': 4, 'tvec__ngram_range': (1, 2), 'tvec__stop_words': None}
# Train Accuracy Score: 0.784623486045287
# Test Accuracy Score: 0.5639810426540285
